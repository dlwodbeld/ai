# %% [markdown]
# <a href="https://colab.research.google.com/github/dlwodbeld/ai/blob/main/%EC%82%AC%EC%A7%84%EC%9D%B8%EC%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Clint ID :Xldp8ZH0vNfLME1lkPBs
# pessword : vqA_ZWVZIE

import os #운영체제 접근
import sys  #시스템 접근
import requests #웹접근
client_id = "Xldp8ZH0vNfLME1lkPBs"
client_secret = "vqA_ZWVZIE"
url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
# url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식


# files = {'image': open('20220214_151138.jpg', 'rb')}  #파일이름
files = {'image': open('download.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":555,"height":832},"faceCount":3},"faces":[{"roi":{"x":203,"y":269,"width":49,"height":49},"landmark":{"leftEye":{"x":217,"y":280},"rightEye":{"x":239,"y":281},"nose":{"x":229,"y":295},"leftMouth":{"x":218,"y":303},"rightMouth":{"x":238,"y":305}},"gender":{"value":"female","confidence":0.999959},"age":{"value":"21~25","confidence":0.421507},"emotion":{"value":"smile","confidence":0.942009},"pose":{"value":"frontal_face","confidence":0.999671}},{"roi":{"x":335,"y":179,"width":50,"height":50},"landmark":{"leftEye":{"x":346,"y":195},"rightEye":{"x":368,"y":195},"nose":{"x":357,"y":207},"leftMouth":{"x":348,"y":220},"rightMouth":{"x":371,"y":217}},"gender":{"value":"male","confidence":0.999869},"age":{"value":"37~41","confidence":0.0520606},"emotion":{"value":"smile","confidence":0.997431},"pose":{"value":"frontal_face","confidence":0.998511}},{"roi":{"x":226,"y":379,"width":60,"height":60},"landmark":null,"gender":{"value":"child","confidence":0.756772},"age":{"v
# ...

# %%
import json

parsed = json.loads(response.text)  #text를 딕셔너리로 변경해줌

print(parsed)
print(type(parsed))
# Out:
# {'info': {'size': {'width': 555, 'height': 832}, 'faceCount': 3}, 'faces': [{'roi': {'x': 203, 'y': 269, 'width': 49, 'height': 49}, 'landmark': {'leftEye': {'x': 217, 'y': 280}, 'rightEye': {'x': 239, 'y': 281}, 'nose': {'x': 229, 'y': 295}, 'leftMouth': {'x': 218, 'y': 303}, 'rightMouth': {'x': 238, 'y': 305}}, 'gender': {'value': 'female', 'confidence': 0.999959}, 'age': {'value': '21~25', 'confidence': 0.421507}, 'emotion': {'value': 'smile', 'confidence': 0.942009}, 'pose': {'value': 'frontal_face', 'confidence': 0.999671}}, {'roi': {'x': 335, 'y': 179, 'width': 50, 'height': 50}, 'landmark': {'leftEye': {'x': 346, 'y': 195}, 'rightEye': {'x': 368, 'y': 195}, 'nose': {'x': 357, 'y': 207}, 'leftMouth': {'x': 348, 'y': 220}, 'rightMouth': {'x': 371, 'y': 217}}, 'gender': {'value': 'male', 'confidence': 0.999869}, 'age': {'value': '37~41', 'confidence': 0.0520606}, 'emotion': {'value': 'smile', 'confidence': 0.997431}, 'pose': {'value': 'frontal_face', 'confidence': 0.998511}}, {'r
# ...

# %%
print(json.dumps(parsed,indent = 4))

# %%
parsed.keys()
dict_keys(['info','faces'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-751b087a65f9> in <module>()
#       1 parsed.keys()
# ----> 2 dict_keys(['info','faces'])
#
# NameError: name 'dict_keys' is not defined

# %%
print(parsed['info'])
# Out:
# {'size': {'width': 555, 'height': 832}, 'faceCount': 3}

# %%
print(parsed['faces'])
# Out:
# [{'roi': {'x': 203, 'y': 269, 'width': 49, 'height': 49}, 'landmark': {'leftEye': {'x': 217, 'y': 280}, 'rightEye': {'x': 239, 'y': 281}, 'nose': {'x': 229, 'y': 295}, 'leftMouth': {'x': 218, 'y': 303}, 'rightMouth': {'x': 238, 'y': 305}}, 'gender': {'value': 'female', 'confidence': 0.999959}, 'age': {'value': '21~25', 'confidence': 0.421507}, 'emotion': {'value': 'smile', 'confidence': 0.942009}, 'pose': {'value': 'frontal_face', 'confidence': 0.999671}}, {'roi': {'x': 335, 'y': 179, 'width': 50, 'height': 50}, 'landmark': {'leftEye': {'x': 346, 'y': 195}, 'rightEye': {'x': 368, 'y': 195}, 'nose': {'x': 357, 'y': 207}, 'leftMouth': {'x': 348, 'y': 220}, 'rightMouth': {'x': 371, 'y': 217}}, 'gender': {'value': 'male', 'confidence': 0.999869}, 'age': {'value': '37~41', 'confidence': 0.0520606}, 'emotion': {'value': 'smile', 'confidence': 0.997431}, 'pose': {'value': 'frontal_face', 'confidence': 0.998511}}, {'roi': {'x': 226, 'y': 379, 'width': 60, 'height': 60}, 'landmark': None, 'ge
# ...

# %%
parsed['faces'][1]
# Out:
# {'age': {'confidence': 0.0520606, 'value': '37~41'},
#  'emotion': {'confidence': 0.997431, 'value': 'smile'},
#  'gender': {'confidence': 0.999869, 'value': 'male'},
#  'landmark': {'leftEye': {'x': 346, 'y': 195},
#   'leftMouth': {'x': 348, 'y': 220},
#   'nose': {'x': 357, 'y': 207},
#   'rightEye': {'x': 368, 'y': 195},
#   'rightMouth': {'x': 371, 'y': 217}},
#  'pose': {'confidence': 0.998511, 'value': 'frontal_face'},
#  'roi': {'height': 50, 'width': 50, 'x': 335, 'y': 179}}

# %%
import matplotlib.pyplot as plt          # 사진(그림) 관련 기본 모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.patches as patches  # 사진 수정 관련 모듈

img = mpimg.imread('download.jpg')     # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10))                      # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                               # 사진틀에 사진 삽입
"""
parsed['faces'][0]['roi']

print(parsed['faces'][0]['roi'])
x,y,w,h = parsed['faces'][0]['roi'].values()    #인식한 얼굴의 roi 위치정보를 변수로 할당

re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r') #그 위치에 사각형을 표시 정보

ax.add_patch(re_face)   #기본 사진에 사각형 정보를 올려 수정
"""
x,y,z,h = parsed['faces'][0]['roi'].values()
age, age_conf = parsed['faces'][0]['age'].values()
gender, gender_conf = parsed['faces'][0]['gender'].values()

# anno = gender + ',' + age
#plt.text(x,y+60,anno,color='YELLOW')
for each in parsed['faces']:
  x,y,w,h = each['roi'].values() 
  age, age_conf = each['age'].values()
  gender, gender_conf = each['gender'].values()
  re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r') #그 위치에 사각형을 표시 정보

  anno = gender + ',' + age
  ax.add_patch(re_face)
  plt.text(x-20,y+70,anno,color='black')
  ax.add_patch(re_face)
